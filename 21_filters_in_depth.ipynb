# %% [markdown]
# **Connected to Elasticsearch**

# %%
from pprint import pprint 
from elasticsearch import Elasticsearch 

es = Elasticsearch("http://localhost:9200")

client_info = es.info()

print("Connected to Elasticsearch!")

pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'T1HeaWnRTOqX_BBgREVVbA',
#  'name': '64c49e436740',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2025-10-21T10:06:21.288851013Z',
#              'build_flavor': 'default',
#              'build_hash': '25d88452371273dd27356c98598287b669a03eae',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '10.3.1',
#              'minimum_index_compatibility_version': '8.0.0',
#              'minimum_wire_compatibility_version': '8.19.0',
#              'number': '9.2.0'}}

# %% [markdown]
# **Creae Index**

# %%
es.indices.delete(index="my_index", ignore_unavailable=True)
es.indices.create(index="my_index")
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %% [markdown]
# **Index data**

# %%
import json 

documents = json.load(open("data/clothes.json"))

operations = []

for document in documents:
    operations.append({"index": {"_index": "my_index"}}) # action 
    operations.append(document)

response = es.bulk(operations=operations)

pprint(response.body)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id': 'GbJGTpoBhG6nlJzo4KAN',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'GrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'G7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'HrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 5,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'H7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 6,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ILJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 7,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'IbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 8,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'IrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 9,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'I7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 10,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 11,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 12,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'JrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 13,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'J7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 14,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 15,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 16,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'KrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 17,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'K7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 18,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 19,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 20,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'LrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 21,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'L7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 22,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 23,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 24,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'MrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 25,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'M7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 26,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 27,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 28,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'NrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 29,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'N7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 30,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'OLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 31,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ObJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 32,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'OrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 33,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'O7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 34,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 35,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 36,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'PrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 37,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'P7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 38,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 39,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 40,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'QrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 41,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Q7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 42,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 43,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 44,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'RrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 45,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'R7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 46,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 47,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 48,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'SrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 49,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'S7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 50,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 51,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 52,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'TrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 53,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'T7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 54,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ULJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 55,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'UbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 56,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'UrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 57,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'U7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 58,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 59,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 60,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'VrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 61,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'V7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 62,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 63,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 64,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'WrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 65,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'W7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 66,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 67,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 68,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'XrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 69,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'X7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 70,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 71,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 72,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'YrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 73,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Y7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 74,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 75,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 76,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ZrJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 77,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'Z7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 78,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'aLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 79,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'abJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 80,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'arJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 81,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'a7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 82,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'bLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 83,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'bbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 84,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'brJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 85,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'b7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 86,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 87,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'cbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 88,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'crJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 89,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'c7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 90,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 91,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'dbJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 92,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'drJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 93,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'd7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 94,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'eLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 95,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ebJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 96,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'erJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 97,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'e7JGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 98,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fLJGTpoBhG6nlJzo4KAO',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 99,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 400}

# %%
count = es.count(index="my_index")
print(f"Number of documents in index: {count.body["count"]}")
# Out:
# Number of documents in index: 100

# %%
response = es.search(
    index="my_index", 
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
        "size": 100,
    }
)

hits = response["hits"]["hits"]
print(f"Total {len(hits)} documents found.")
# Out:
# Total 23 documents found.

# %% [markdown]
# Here, we apply multiple filters using an AND operation to retain documents where the brand is Adidas and the color is yellow.

# %%
response = es.search(
    index="my_index", 
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "brand":  "adidas"
                        }
                    },
                    {
                        "term": {
                            "color": "yellow"
                        }
                    }
                ]
            }
        }
    }
)

hits = response["hits"]["hits"]

print(hits[0]["_source"])

print(f"Total {len(hits)} documents found.")
# Out:
# {'brand': 'adidas', 'color': 'yellow', 'model': 'model_15'}
# Total 6 documents found.

# %% [markdown]
# **Post filters**
# #
# In this example, we'll explore the use of filters, aggregations, filtered aggregations, and post-filters.
#
# We start by narrowing our search to documents where the brand is gucci. Next, we apply aggregations to determine the document count for each color. We then define a filtered aggregation, color_red, which counts the models in documents where the color is red.
#
# Finally, a post_filter is used after performing the aggregations, refining the search results to include only documents with the color red.

# %%
response = es.search(
    index="my_index", 
    body={
        "query": {
            "bool": {
                "filter": {
                    "term": {
                        "brand": "gucci"
                    }
                }
            }
        },
        "aggs": {
            "colors": {
                "terms": {
                    "field": "color.keyword"
                }
            },
            "color_red": {
                "filter": {
                    "term": {
                        "color.keyword": "red"
                    }
                },
                "aggs": {
                    "models": {
                        "terms": {
                            "field": "model.keyword"
                        }
                    }
                }
            }
        }
    }
)

hits = response["hits"]["hits"]

pprint(response.body)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'color_red': {'doc_count': 12,
#                                 'models': {'buckets': [{'doc_count': 3,
#                                                         'key': 'model_1'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_14'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_16'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_2'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_26'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_28'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_3'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_4'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_6'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_8'}],
#                                            'doc_count_error_upper_bound': 0,
#                                            'sum_other_doc_count': 0}},
#                   'colors': {'buckets': [{'doc_count': 12, 'key': 'red'},
#                                          {'doc_count': 8, 'key': 'blue'},
#                                          {'doc_count': 6, 'key': 'green'},
#                                          {'doc_count': 4, 'key': 'yellow'}],
#                              'doc_count_error_upper_bound': 0,
#                              'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'GbJGTpoBhG6nlJzo4KAN',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'GrJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'blue',
#                                 'model': 'model_2'}},
#                    {'_id': 'G7JGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_3'}},
#                    {'_id': 'HLJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'green',
#                                 'model': 'model_4'}},
#                    {'_id': 'HbJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'HrJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'yellow',
#                                 'model': 'model_2'}},
#                    {'_id': 'IbJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'blue',
#                                 'model': 'model_3'}},
#                    {'_id': 'IrJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_4'}},
#                    {'_id': 'JbJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'LbJGTpoBhG6nlJzo4KAO',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'blue',
#                                 'model': 'model_16'}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 30}},
#  'timed_out': False,
#  'took': 91}

# %%
colors_aggregation = response.body['aggregations']['colors']['buckets']
pprint(colors_aggregation)
# Out:
# [{'doc_count': 12, 'key': 'red'},
#  {'doc_count': 8, 'key': 'blue'},
#  {'doc_count': 6, 'key': 'green'},
#  {'doc_count': 4, 'key': 'yellow'}]

# %%
color_red_aggregation = response.body['aggregations']['color_red']['models']['buckets']
pprint(color_red_aggregation)
# Out:
# [{'doc_count': 3, 'key': 'model_1'},
#  {'doc_count': 1, 'key': 'model_14'},
#  {'doc_count': 1, 'key': 'model_16'},
#  {'doc_count': 1, 'key': 'model_2'},
#  {'doc_count': 1, 'key': 'model_26'},
#  {'doc_count': 1, 'key': 'model_28'},
#  {'doc_count': 1, 'key': 'model_3'},
#  {'doc_count': 1, 'key': 'model_4'},
#  {'doc_count': 1, 'key': 'model_6'},
#  {'doc_count': 1, 'key': 'model_8'}]

# %%
hits = response.body['hits']['hits']
for hit in hits:
    print(f"""Shirt brand: {hit['_source']['brand']}, color: {
          hit['_source']['color']}, and model: {hit['_source']['model']}""")
# Out:
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: blue, and model: model_2
# Shirt brand: gucci, color: red, and model: model_3
# Shirt brand: gucci, color: green, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: yellow, and model: model_2
# Shirt brand: gucci, color: blue, and model: model_3
# Shirt brand: gucci, color: red, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: blue, and model: model_16
