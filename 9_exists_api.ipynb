# %% [markdown]
# **Connect to Elasticsearch**

# %%
from pprint import pprint 
from elasticsearch import Elasticsearch

es = Elasticsearch("http://localhost:9200")

client_info = es.info() 

print("Connected to Elasticsearch!")
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'T1HeaWnRTOqX_BBgREVVbA',
#  'name': '64c49e436740',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2025-10-21T10:06:21.288851013Z',
#              'build_flavor': 'default',
#              'build_hash': '25d88452371273dd27356c98598287b669a03eae',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '10.3.1',
#              'minimum_index_compatibility_version': '8.0.0',
#              'minimum_wire_compatibility_version': '8.19.0',
#              'number': '9.2.0'}}

# %% [markdown]
# **Create Index with auto Mappings**

# %%
es.indices.delete(index="my_index", ignore_unavailable=True)
es.indices.create(index="my_index")
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %%
document = {
    "fast_name": "Shamim",
    "last_name": "Islam"
}

response = es.index(index="my_index", body=document)
response
# Out:
# ObjectApiResponse({'_index': 'my_index', '_id': 'UR17PJoBZCw2coN1ErJx', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1})

# %% [markdown]
# **Exist API**

# %%
response = es.indices.exists(index="my_index")
response.body
# Out:
# True

# %%
response = es.exists(index="my_index", id="UR17PJoBZCw2coN1ErJx")
response.body
# Out:
# True

# %%
response = es.exists(index="my_index", id="wrong_document_id_does_not_exist")
response.body
# Out:
# False
